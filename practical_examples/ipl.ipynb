# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('teams.csv')

# %%
df
# Out:
#    teams
# 0    rcb
# 1     mi
# 2    csk
# 3    srh
# 4     dd
# 5     mi
# 6  jammu
# 7     hp

# %%
df.drop_duplicates(inplace=True, ignore_index=True)

# %%
df
# Out:
#    teams
# 0    rcb
# 1     mi
# 2    csk
# 3    srh
# 4     dd
# 5  jammu
# 6     hp

# %%
df['team_id'] = np.arange(len(df))

# %%
df
# Out:
#    teams  team_id
# 0    rcb        0
# 1     mi        1
# 2    csk        2
# 3    srh        3
# 4     dd        4
# 5  jammu        5
# 6     hp        6

# %%
game = df.merge(df, how='cross', suffixes=['_left', '_right'])

# %%
game = game[game['team_id_left'] < game['team_id_right']]

# %%
game = game[['teams_left', 'teams_right']]

# %%
game
# Out:
#    teams_left teams_right
# 1         rcb          mi
# 2         rcb         csk
# 3         rcb         srh
# 4         rcb          dd
# 5         rcb       jammu
# 6         rcb          hp
# 9          mi         csk
# 10         mi         srh
# 11         mi          dd
# 12         mi       jammu
# 13         mi          hp
# 17        csk         srh
# 18        csk          dd
# 19        csk       jammu
# 20        csk          hp
# 25        srh          dd
# 26        srh       jammu
# 27        srh          hp
# 33         dd       jammu
# 34         dd          hp
# 41      jammu          hp
