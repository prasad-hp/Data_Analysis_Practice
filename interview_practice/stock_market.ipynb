# %% [markdown]
# ## Stock Market Analysis

# %%
import yfinance as yf

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
data = yf.Tickers(['META', "AAPL", 'AMZN', 'NVDA', 'NFLX', 'GOOG'])

# %%
data
# Out:
# yfinance.Tickers object <META,AAPL,AMZN,NVDA,NFLX,GOOG>

# %%
ticks = ['META', "AAPL", 'AMZN', 'NVDA', 'NFLX', 'GOOG']

# %%
stock_data = yf.download(ticks, period='10y')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  6 of 6 completed

# %%
stock_data.head()
# Out:
# Price           Close                                                        \
# Ticker           AAPL       AMZN       GOOG       META       NFLX      NVDA
# Date
# 2015-06-17  28.510983  21.390499  26.306627  81.343750  94.271431  0.522262
# 2015-06-18  28.640877  21.969500  26.677923  82.457634  94.742859  0.530974
# 2015-06-19  28.354200  21.746000  26.675934  82.059822  93.871429  0.529280
# 2015-06-22  28.580406  21.814501  26.750490  84.277649  96.414284  0.527102
# 2015-06-23  28.450508  22.299500  26.864313  87.400513  97.312859  0.513550
#
# Price            High                                   ...       Open  \
# Ticker           AAPL       AMZN       GOOG       META  ...       GOOG
# Date                                                    ...
# 2015-06-17  28.640882  21.567499  26.392120  81.771404  ...  26.312096
# 2015-06-18  28.737183  21.986500  26.748503  82.736105  ...  26.393115
# 2015-06-19  28.627440  22.249500  26.753474  82.527259  ...  26.701781
# ...

# %%
stock_data.to_csv('stock_data_10y.csv')

# %%
stock_data.drop(columns=['High', 'Open'], inplace=True)

# %%
stock_data.head()
# Out:
# Price           Close                                                        \
# Ticker           AAPL       AMZN       GOOG       META       NFLX      NVDA
# Date
# 2015-06-17  28.510983  21.390499  26.306627  81.343750  94.271431  0.522262
# 2015-06-18  28.640877  21.969500  26.677923  82.457634  94.742859  0.530974
# 2015-06-19  28.354200  21.746000  26.675934  82.059822  93.871429  0.529280
# 2015-06-22  28.580406  21.814501  26.750490  84.277649  96.414284  0.527102
# 2015-06-23  28.450508  22.299500  26.864313  87.400513  97.312859  0.513550
#
# Price             Low                                                        \
# Ticker           AAPL       AMZN       GOOG       META       NFLX      NVDA
# Date
# 2015-06-17  28.385560  21.237499  26.099856  80.896201  93.957146  0.514760
# 2015-06-18  28.493060  21.470501  26.382677  81.124941  94.368568  0.525166
# 2015-06-19  28.309408  21.662001  26.493021  81.671951  93.821426  0.524440
# ...

# %%
stock_data.dtypes
# Out:
# Price   Ticker
# Close   AAPL      float64
#         AMZN      float64
#         GOOG      float64
#         META      float64
#         NFLX      float64
#         NVDA      float64
# Low     AAPL      float64
#         AMZN      float64
#         GOOG      float64
#         META      float64
#         NFLX      float64
#         NVDA      float64
# Volume  AAPL        int64
#         AMZN        int64
#         GOOG        int64
#         META        int64
#         NFLX        int64
#         NVDA        int64
# dtype: object

# %%
stock_data['Date'] = stock_data.index

# %%
stock_data.dtypes
# Out:
# Price   Ticker
# Close   AAPL             float64
#         AMZN             float64
#         GOOG             float64
#         META             float64
#         NFLX             float64
#         NVDA             float64
# Low     AAPL             float64
#         AMZN             float64
#         GOOG             float64
#         META             float64
#         NFLX             float64
#         NVDA             float64
# Volume  AAPL               int64
#         AMZN               int64
#         GOOG               int64
#         META               int64
#         NFLX               int64
#         NVDA               int64
# Date              datetime64[ns]
# dtype: object

# %%
fig, ax = plt.subplots(figsize=(15, 5))
sns.lineplot(stock_data['Close'])
plt.title("Price Trend Over Last 10 Years")
plt.ylabel("Stock Price")
plt.grid(visible=True)

# %%
stock_data['MA20_NVDA'] = stock_data['Close']['NVDA'].rolling(window=20).mean()
stock_data['MA50_NVDA'] = stock_data['Close']['NVDA'].rolling(50).mean()

# %%
fig, ax = plt.subplots(figsize=(15,8))
sns.lineplot([stock_data['Close']['NVDA']])
sns.lineplot(stock_data['MA20_NVDA'])
sns.lineplot(stock_data['MA50_NVDA'])
plt.grid()

# %%
stock_weekly = stock_data['Close'].resample('W').last()

# %%
stock_weekly
# Out:
# Ticker            AAPL        AMZN        GOOG        META         NFLX  \
# Date
# 2015-06-21   28.354200   21.746000   26.675934   82.059822    93.871429
# 2015-06-28   28.387794   21.905001   26.427412   87.529800    93.088570
# 2015-07-05   28.318367   21.885500   26.015360   86.813744    94.044289
# 2015-07-12   27.610630   22.175501   26.349871   87.470139    97.228569
# 2015-07-19   29.030573   24.150499   33.447681   94.451828   114.769997
# ...                ...         ...         ...         ...          ...
# 2025-05-25  195.270004  200.990005  169.386398  626.577881  1185.390015
# 2025-06-01  200.850006  205.009995  172.642487  646.992188  1207.229980
# 2025-06-08  203.919998  213.570007  174.709991  697.173584  1241.469971
# 2025-06-15  196.449997  212.100006  175.880005  682.344971  1212.150024
# 2025-06-22  198.419998  216.100006  177.940002  702.119995  1225.349976
#
# Ticker            NVDA
# Date
# 2015-06-21    0.529280
# 2015-06-28    0.501933
# ...

# %%
fig, ax = plt.subplots(figsize=(15,8))
sns.lineplot(stock_weekly['NVDA'].pct_change()*100)
plt.grid()

# %%
stock_data.drop(columns='Low',inplace=True)

# %%
stock_data.head()
# Out:
# Price           Close                                                        \
# Ticker           AAPL       AMZN       GOOG       META       NFLX      NVDA
# Date
# 2015-06-17  28.510983  21.390499  26.306627  81.343750  94.271431  0.522262
# 2015-06-18  28.640877  21.969500  26.677923  82.457634  94.742859  0.530974
# 2015-06-19  28.354200  21.746000  26.675934  82.059822  93.871429  0.529280
# 2015-06-22  28.580406  21.814501  26.750490  84.277649  96.414284  0.527102
# 2015-06-23  28.450508  22.299500  26.864313  87.400513  97.312859  0.513550
#
# Price          Volume                                                     \
# Ticker           AAPL      AMZN      GOOG      META      NFLX       NVDA
# Date
# 2015-06-17  131672400  43718000  25884000  18350300   9905000  233544000
# 2015-06-18  141628800  67568000  36662000  26782600   8962800  299404000
# 2015-06-19  218867600  89902000  37870000  23353200  19814900  355656000
# ...

# %%
data.tickers['AAPL'].info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...
